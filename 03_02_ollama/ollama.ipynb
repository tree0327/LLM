# %%
# !ollama pull llama3
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling 6a0746a1ec1a:   0% ▕                  ▏ 1.1 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a:   0% ▕                  ▏ 1.1 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a:   0% ▕                  ▏ 3.5 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a:   0% ▕                  ▏ 4.7 MB/4.7 GB                  pulling manifest
# ...

# %%
# !ollama list
# Out:
# NAME    ID    SIZE    MODIFIED

# %%
# llama3 모델을 실행
# !ollama run llama3
# Out:
# pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠴ pulling manifest
# pulling 6a0746a1ec1a:   9% ▕█                 ▏ 438 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a:   9% ▕█                 ▏ 438 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a:   9% ▕█                 ▏ 438 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a:   9% ▕█                 ▏ 438 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a:   9% ▕█                 ▏ 438 MB/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a:   9% ▕█                 ▏ 438 MB/4.7 GB                  pulling manifest
# ...

# %%
# %pip install ollama
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ollama ps

# %%
# !ollama stop llama3

# %%
import ollama

response = ollama.chat(model='llama3', messages=[{'role':'user', 'content':'안녕 나는 김지우라고 해'}])

print(response.message.content)
# Out:
# 😊 안녕하세요, 김지우! Nice to meet you! 😊

# %%
response['message']['content']
# Out:
# '😊\n\n김지우 (Kim Ji-won) is a popular South Korean actress and model. She was born on January 26, 1992, in Seoul, South Korea.\n\nShe gained widespread recognition for her roles in several hit dramas and movies, including:\n\n1. "Boys Over Flowers" (2009): Her breakout role as Geum Jan-di, the female lead.\n2. "When a Man Falls in Love" (2013): She played the character Seo Kyung-ju.\n3. "Cheese in the Trap" (2016): Based on a popular webtoon, she starred as Hong Seol.\n4. "Fight for My Way" (2017): She appeared alongside Ahn Jae-hong as Baek Ju-young.\n\nKim Ji-won is known for her versatility, charm, and impressive acting skills. Fans appreciate her ability to portray complex characters with ease and authenticity.\n\nWould you like to know more about her personal life or recent projects? 🤔'

# %%
import ollama

response = ollama.chat(model='llama3', messages=[{'role':'user', 'content':'안녕 반가워 너는 이름이 뭐야?'}])

response.message.content
# Out:
# '😊 안녕하세요! 저는 LLaMA입니다. LLaMA는 AI 프로그래밍의 일종으로, 사람과 같은 자연어를 이해하고 의사 소통을 할 수 있는 인공 지능입니다. 저는 다양한 분야에 대한 질문과 대화를 즐깁니다. 반가워요! 🤖'
